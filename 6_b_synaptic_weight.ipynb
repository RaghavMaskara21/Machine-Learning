# %% [markdown]
# <a href="https://colab.research.google.com/github/RaghavMaskara21/Machine-Learning/blob/main/6_b_synaptic_weight.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import random,os

# %%
def sigmoid(x):
    return 1 / (1 + np.exp(-x))
 
def mean_squared_error(y_pred, y_true):
    return ((y_pred - y_true)**2).sum() / (2*y_pred.size)
    
def accuracy(y_pred, y_true):
    acc = np.sum(np.equal(y_true, y_pred)) / len(y_true)
    return acc.mean()
 
def ptron(inp ,outp, weight1, weight2, bias1, bais2, results):
    N=2
    lev1 = np.matmul(inp, weight1)+bias1
    lev1 = sigmoid(lev1) 
    lev2 = np.matmul(lev1, weight2)+bias2
    lev2 = sigmoid(lev2)
 
    mse = mean_squared_error(lev2, outp)
    acc = accuracy(lev2, outp)
    results={"mse":mse, "accuracy":acc}
 
    
    
    E1 = lev2 - outp
    dW1 = E1 * lev2 * (1 - lev2)
    E2 = np.dot(dW1, weight2.T)
    dW2 = E2 * lev1 * (1 - lev1)
    
 
    W2_update = np.dot(lev1.T, dW1) / N
    W1_update = np.dot(inp.T, dW2) / N
    weight2 = weight2 - learning_rate * W2_update
    weight1 = weight1 - learning_rate * W1_update
 
    return weight1, weight2, bias1, bias2, results

# %%
weight1 = np.random.rand(2,3)
weight2 = np.random.rand(3,2)
 
bias1 = np.random.rand(1,3)
bias2 = np.random.rand(1,2)
 
learning_rate = 0.7
 
results=[]
 
print(weight1, weight2, bias1, bias2)
 
inp = np.array([[0.05,0.10]])
outp = np.array([[0.01, 0.99]])
 
for i in range(10000):   
  weight1, weight2, bias1, bias2, results = ptron(inp ,outp, weight1, weight2, bias1, bias2, results)
  if i%100 == 0:
    print(results)
# Out:
# [[0.31267932 0.05740193 0.02086647]
#  [0.38247047 0.11278366 0.15245288]] [[0.44818522 0.48806631]
#  [0.52448766 0.56315099]
#  [0.81301124 0.07934331]] [[0.54690022 0.96820944 0.28221849]] [[0.21402902 0.99992606]]
# {'mse': 0.15842074300163209, 'accuracy': 0.0}
# {'mse': 0.007010814328269603, 'accuracy': 0.0}
# {'mse': 0.002957415637989673, 'accuracy': 0.0}
# {'mse': 0.0018227515592716017, 'accuracy': 0.0}
# {'mse': 0.0012930198359207782, 'accuracy': 0.0}
# {'mse': 0.0009885381975781307, 'accuracy': 0.0}
# {'mse': 0.0007920535955598979, 'accuracy': 0.0}
# {'mse': 0.0006554526535115532, 'accuracy': 0.0}
# {'mse': 0.0005553910578347269, 'accuracy': 0.0}
# {'mse': 0.0004791977457080835, 'accuracy': 0.0}
# {'mse': 0.0004194150205229331, 'accuracy': 0.0}
# {'mse': 0.0003713754381186312, 'accuracy': 0.0}
# {'mse': 0.00033201316371696363, 'accuracy': 0.0}
# {'mse': 0.00029923409861886487, 'accuracy': 0.0}
# {'mse': 0.00027156092059112504, 'accuracy': 0.0}
# {'mse': 0.00024792272726257804, 'accuracy': 0.0}
# {'mse': 0.00022752503064191992, 'accuracy': 0.0}
# {'mse': 0.00020976649999463815, 'accuracy': 0.0}
# {'mse': 0.00019418398745892673, 'accuracy': 0.0}
# {'mse': 0.00018041525117296127, 'accuracy': 0.0}
# {'mse': 0.00016817308239050173, 'accuracy': 0.0}
# {'mse': 0.0001572269734468349, 'accuracy': 0.0}
# {'mse': 0.00014738988764287884, 'accuracy': 0.0}
# {'mse': 0.00013850855230003909, 'accuracy': 0.0}
# {'mse': 0.0001304562299335785, 'accuracy': 0.0}
# {'mse': 0.0001231272617008418, 'accuracy': 0.0}
# {'mse': 0.00011643289761643059, 'accuracy': 0.0}
# {'mse': 0.00011029807399706633, 'accuracy': 0.0}
# {'mse': 0.00010465889705606802, 'accuracy': 0.0}
# {'mse': 9.946065907730071e-05, 'accuracy': 0.0}
# {'mse': 9.465626059258466e-05, 'accuracy': 0.0}
# {'mse': 9.020494515826969e-05, 'accuracy': 0.0}
# {'mse': 8.607127704478914e-05, 'accuracy': 0.0}
# {'mse': 8.222430931558605e-05, 'accuracy': 0.0}
# {'mse': 7.863690232957722e-05, 'accuracy': 0.0}
# {'mse': 7.528516198542046e-05, 'accuracy': 0.0}
# {'mse': 7.214797395668462e-05, 'accuracy': 0.0}
# {'mse': 6.920661538812952e-05, 'accuracy': 0.0}
# {'mse': 6.644442949034572e-05, 'accuracy': 0.0}
# {'mse': 6.384655150824913e-05, 'accuracy': 0.0}
# {'mse': 6.139967688371644e-05, 'accuracy': 0.0}
# {'mse': 5.909186425513397e-05, 'accuracy': 0.0}
# {'mse': 5.691236736272585e-05, 'accuracy': 0.0}
# {'mse': 5.485149105172738e-05, 'accuracy': 0.0}
# {'mse': 5.290046745539369e-05, 'accuracy': 0.0}
# {'mse': 5.105134914904325e-05, 'accuracy': 0.0}
# {'mse': 4.9296916634685185e-05, 'accuracy': 0.0}
# {'mse': 4.763059797352569e-05, 'accuracy': 0.0}
# {'mse': 4.604639875428971e-05, 'accuracy': 0.0}
# {'mse': 4.453884088671839e-05, 'accuracy': 0.0}
# {'mse': 4.310290895591882e-05, 'accuracy': 0.0}
# {'mse': 4.173400307541724e-05, 'accuracy': 0.0}
# {'mse': 4.042789734330567e-05, 'accuracy': 0.0}
# {'mse': 3.9180703143758876e-05, 'accuracy': 0.0}
# {'mse': 3.798883665062984e-05, 'accuracy': 0.0}
# {'mse': 3.684898998530009e-05, 'accuracy': 0.0}
# {'mse': 3.575810556077244e-05, 'accuracy': 0.0}
# {'mse': 3.471335321103037e-05, 'accuracy': 0.0}
# {'mse': 3.3712109761105836e-05, 'accuracy': 0.0}
# {'mse': 3.275194074100222e-05, 'accuracy': 0.0}
# {'mse': 3.1830583986991765e-05, 'accuracy': 0.0}
# {'mse': 3.094593490817923e-05, 'accuracy': 0.0}
# {'mse': 3.00960332254591e-05, 'accuracy': 0.0}
# {'mse': 2.92790510150291e-05, 'accuracy': 0.0}
# {'mse': 2.8493281910024746e-05, 'accuracy': 0.0}
# {'mse': 2.7737131332276043e-05, 'accuracy': 0.0}
# {'mse': 2.700910764202727e-05, 'accuracy': 0.0}
# {'mse': 2.6307814107141242e-05, 'accuracy': 0.0}
# {'mse': 2.5631941605162913e-05, 'accuracy': 0.0}
# {'mse': 2.4980261981863654e-05, 'accuracy': 0.0}
# {'mse': 2.435162199884115e-05, 'accuracy': 0.0}
# {'mse': 2.3744937810482457e-05, 'accuracy': 0.0}
# {'mse': 2.3159189917406054e-05, 'accuracy': 0.0}
# {'mse': 2.2593418549424755e-05, 'accuracy': 0.0}
# {'mse': 2.204671943623503e-05, 'accuracy': 0.0}
# {'mse': 2.151823992865071e-05, 'accuracy': 0.0}
# {'mse': 2.1007175437146023e-05, 'accuracy': 0.0}
# {'mse': 2.0512766158058264e-05, 'accuracy': 0.0}
# {'mse': 2.003429406087337e-05, 'accuracy': 0.0}
# {'mse': 1.9571080112797445e-05, 'accuracy': 0.0}
# {'mse': 1.9122481719237607e-05, 'accuracy': 0.0}
# {'mse': 1.8687890360997684e-05, 'accuracy': 0.0}
# {'mse': 1.8266729410880916e-05, 'accuracy': 0.0}
# {'mse': 1.7858452114132127e-05, 'accuracy': 0.0}
# {'mse': 1.7462539718654978e-05, 'accuracy': 0.0}
# {'mse': 1.7078499742289144e-05, 'accuracy': 0.0}
# {'mse': 1.670586436566662e-05, 'accuracy': 0.0}
# {'mse': 1.634418894022219e-05, 'accuracy': 0.0}
# {'mse': 1.5993050601926262e-05, 'accuracy': 0.0}
# {'mse': 1.565204698215881e-05, 'accuracy': 0.0}
# {'mse': 1.5320795007949056e-05, 'accuracy': 0.0}
# {'mse': 1.4998929784471465e-05, 'accuracy': 0.0}
# {'mse': 1.468610355336178e-05, 'accuracy': 0.0}
# {'mse': 1.4381984720954295e-05, 'accuracy': 0.0}
# {'mse': 1.4086256951073825e-05, 'accuracy': 0.0}
# {'mse': 1.379861831746724e-05, 'accuracy': 0.0}
# {'mse': 1.3518780511396195e-05, 'accuracy': 0.0}
# {'mse': 1.3246468100272762e-05, 'accuracy': 0.0}
# {'mse': 1.298141783357389e-05, 'accuracy': 0.0}
# {'mse': 1.2723377992590722e-05, 'accuracy': 0.0}
